# %%
import sys
import time
import json
from Admin import Admin
from User import User
print("*"*50+"\n Welcome To FOODIEZ\n"+"*"*50)

demo1 = User()
print(demo1.login("iqrar@gmail.com","Password"))


while True:
    l = []
    rs = 0
    order_history = {}
    print("+="*70)
    print("Press P For Place New Order")
    print("Press U For Update Profile")
    print("Press H For Get History From App")
    print("Press E For Exit From App")
    print("=*"*70)
    user_input = input("Press Button :")
    if user_input ==  "P" or user_input =="p":
        with open("Admin.json","r") as f:
            temp = json.load(f)
        print("1. ",temp["1"]["Quantity "] ," ",temp["1"]["Name"]," ",temp["B_094"]["Price "],"Rupee")
        print("2. ",temp["2"]["Quantity "] ," ",temp["2"]["Name"]," ",temp["B_201"]["Price "],"Rupee")
        print("3. ",temp["3"]["Quantity "] ," ",temp["3"]["Name"]," ",temp["B_074"]["Price "],"Rupee")
        print("4. ",temp["4"]["Quantity "] ," ",temp["4"]["Name"]," ",temp["B_619"]["Price "],"Rupee")
        print("5. ",temp["5"]["Quantity "] ," ",temp["5"]["Name"]," ",temp["B_017"]["Price "],"Rupee")
        print("6. ",temp["6"]["Quantity "] ," ",temp["6"]["Name"]," ",temp["B_783"]["Price "],"Rupee")
        print("7. ",temp["7"]["Quantity "] ," ",temp["7"]["Name"]," ",temp["B_083"]["Price "],"Rupee")
        print("8. ",temp["8"]["Quantity "] ," ",temp["8"]["Name"]," ",temp["B_820"]["Price "],"Rupee")
        print("9. ",temp["9"]["Quantity "] ," ",temp["9"]["Name"]," ",temp["B_839"]["Price "],"Rupee")
        print("10. ",temp["10"]["Quantity "] ," ",temp["10"]["Name"]," ",temp["B_689"]["Price "],"Rupee")
        print("Press 0 for End ")
        print()
        print("*"*50+"\nPress 1 For Place Your Order\n"+"*"*50)
        ch = 1
        while ch!=0:
            ch = int(input("Press Button For Order"))
            if ch==1 :
                rs+=250
                l.append(temp["1"]["Name"])

            elif ch==2 :
                rs+=300
                l.append(temp["2"]["Name"])
                
            elif ch==3:
                rs+=14
                l.append(temp["3"]["Name"])   
            
            elif ch==4:
                rs+=12
                l.append(temp["4"]["Name"])
            
            elif ch==5:
                rs+=120
                l.append(temp["5"]["Name"])
            
            elif ch==6:
                rs+=25
                l.append(temp["6"]["Name"])
          
            elif ch==7:
                rs+=30
                l.append(temp["7"]["Name"])

            elif ch==8:
                rs+=140
                l.append(temp["8"]["Name"])
            
            elif ch==9:
                rs+=20
                l.append(temp["9"]["Name"])
            
            elif ch==10:
                rs+=25
                l.append(temp["10"]["Name"])
                        
            elif ch==1:
                print(l)
                order_history={"Order History":l,"Total Bill":rs}
                with open("history.json","w") as f:
                    json.dump(order_history,f,indent=4)
                time.sleep(2)
                print("Total Bill : - ",rs)
                print("Your Order Got Placed\n"+"*"*50)
                print("You'll Get Your Order Soon")
                print()
                print("*"*50+"\nThanks For Using FOODIEZ\n"+"*"*50)
                break

    elif user_input=="h" or user_input=="H":
        with open("history.json","r")  as f:
            temp =json.load(f)
            print(temp)            

    elif user_input=="U" or user_input=="u":
        demo1.update_profile()

    elif user_input=="E" or user_input=="e":
        time.sleep(3)
        print("*"*50+"\nThanks For Using FOODIEZ\n"+"*"*50)
        sys.exit()
