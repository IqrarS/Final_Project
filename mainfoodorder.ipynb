# %%
import sys
import time
import json
from Admin import Admin
from User import User
print("*"*50+"\n Welcome To FOODIEZ\n"+"*"*50)

demo1 = User()
print(demo1.login("iqrar@outlook.com","Password"))


while True:
    l = []
    rs = 0
    order_history = {}
    print("+="*70)
    print("Press P For Place New Order")
    print("Press U For Update Profile")
    print("Press H For Get History From App")
    print("Press E For Exit From App")
    print("=*"*70)
    user_input = input("Press Button :")
    if user_input ==  "P" or user_input =="p":
        with open("Admin.json","r") as f:
            temp = json.load(f)
        print("1. ",temp["B_094"]["Quantity "] ," ",temp["B_094"]["Name"]," ",temp["B_094"]["Price "],"Rupee")
        print("2. ",temp["B_201"]["Quantity "] ," ",temp["B_201"]["Name"]," ",temp["B_201"]["Price "],"Rupee")
        print("3. ",temp["B_074"]["Quantity "] ," ",temp["B_074"]["Name"]," ",temp["B_074"]["Price "],"Rupee")
        print("4. ",temp["B_619"]["Quantity "] ," ",temp["B_619"]["Name"]," ",temp["B_619"]["Price "],"Rupee")
        print("5. ",temp["B_017"]["Quantity "] ," ",temp["B_017"]["Name"]," ",temp["B_017"]["Price "],"Rupee")
        print("6. ",temp["B_783"]["Quantity "] ," ",temp["B_783"]["Name"]," ",temp["B_783"]["Price "],"Rupee")
        print("7. ",temp["B_083"]["Quantity "] ," ",temp["B_083"]["Name"]," ",temp["B_083"]["Price "],"Rupee")
        print("8. ",temp["B_820"]["Quantity "] ," ",temp["B_820"]["Name"]," ",temp["B_820"]["Price "],"Rupee")
        print("9. ",temp["B_839"]["Quantity "] ," ",temp["B_839"]["Name"]," ",temp["B_839"]["Price "],"Rupee")
        print("10. ",temp["B_689"]["Quantity "] ," ",temp["B_689"]["Name"]," ",temp["B_689"]["Price "],"Rupee")
        print("Press 0 for End ")
        print()
        print("*"*50+"\nPress 1 For Place Your Order\n"+"*"*50)
        ch = 1
        while ch!=0:
            ch = int(input(" Press Button For Order----> "))
            if ch==1 :
                rs+=250
                l.append(temp["B_094"]["Name"])

            elif ch==2 :
                rs+=300
                l.append(temp["B_201"]["Name"])
                
            elif ch==3:
                rs+=14
                l.append(temp["B_074"]["Name"])   
            
            elif ch==4:
                rs+=12
                l.append(temp["B_619"]["Name"])
            
            elif ch==5:
                rs+=120
                l.append(temp["B_017"]["Name"])
            
            elif ch==6:
                rs+=25
                l.append(temp["B_783"]["Name"])
          
            elif ch==7:
                rs+=30
                l.append(temp["B_083"]["Name"])

            elif ch==8:
                rs+=140
                l.append(temp["B_820"]["Name"])
            
            elif ch==9:
                rs+=20
                l.append(temp["B_839"]["Name"])
            
            elif ch==10:
                rs+=25
                l.append(temp["B_689"]["Name"])
            
            elif ch==11:
                rs+=40
                l.append(temp["B_937"]["Name"])
            
            elif ch==12:
                rs+=50
                l.append(temp["B_976"]["Name"])
                        
            elif ch==1:
                print(l)
                order_history={"Order History":l,"Total Bill":rs}
                with open("history.json","w") as f:
                    json.dump(order_history,f,indent=4)
                time.sleep(2)
                print("Total Bill : - ",rs)
                print("Your Order Got Placed\n"+"*"*50)
                print("You'll Get Your Order Soon")
                print()
                print("*"*50+"\nThanks For Using FOODIEZ\n"+"*"*50)
                break

    elif user_input=="h" or user_input=="H":
        with open("history.json","r")  as f:
            temp =json.load(f)
            print(temp)            

    elif user_input=="U" or user_input=="u":
        demo1.update_profile()

    elif user_input=="E" or user_input=="e":
        time.sleep(3)
        print("*"*50+"\nThanks For Using FOODIEZ\n"+"*"*50)
        sys.exit()
# Out:
#   File "C:\Users\is\AppData\Local\Temp\ipykernel_11152\1374476358.py", line 13
#     l = []
#     ^
# SyntaxError: invalid non-printable character U+00A0
